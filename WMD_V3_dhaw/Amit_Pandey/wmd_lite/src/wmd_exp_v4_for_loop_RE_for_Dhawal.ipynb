# %%
import os

os.listdir("/scratch/Amit_Pandey/wmd_lite/files")
# Out:
# ['bbcsport_labels.npy',
#  'Train_BBCsport_sent.npy',
#  'bbcsport_dataset.json',
#  'data.json',
#  'Test_BBCsport_label.npy',
#  'bbcsport_sentences.npy',
#  'glove.6B.zip',
#  'glove.6B.50d.txt',
#  'model.npy',
#  'reduced_glove_embedding_300.json',
#  'model.npz',
#  'google300w2v.kv',
#  'glove.6B.200d.txt',
#  'glove.6B.100d.txt',
#  'wmd_exp_v4_for_loop_RE_for_Dhawal.ipynb',
#  'glove.6B.300d.txt',
#  'bbcsport',
#  'Train_BBCsport_label.npy',
#  'Test_BBCsport_sent.npy']

# %%
os.listdir("../")
# Out:
# ['.ipynb_checkpoints', 'src', 'results', 'Files_Detail.txt']

# %%
os.listdir("/scratch/Amit_Pandey/gensim-data/word2vec-google-news-300/")
# Out:
# ['word2vec-google-news-300.gz',
#  'GoogleNews-vectors-negative300.bin',
#  '__pycache__',
#  '__init__.py']

# %%
os.listdir("../results")
# Out:
# ['test_result.pickle']

# %% [markdown]
# ## Important step to write path into NLTK path. This is where nltk looks for data. Else throws error. I have kept the nltk data on scratch.

# %%
import nltk
print(nltk.data.path)
nltk.data.path.append("/scratch/Amit_Pandey/nltk_data")

print(nltk.data.path)
# Out:
# ['/home2/dhawals1939/nltk_data', '/home2/dhawals1939/miniconda3/nltk_data', '/home2/dhawals1939/miniconda3/share/nltk_data', '/home2/dhawals1939/miniconda3/lib/nltk_data', '/usr/share/nltk_data', '/usr/local/share/nltk_data', '/usr/lib/nltk_data', '/usr/local/lib/nltk_data']
# ['/home2/dhawals1939/nltk_data', '/home2/dhawals1939/miniconda3/nltk_data', '/home2/dhawals1939/miniconda3/share/nltk_data', '/home2/dhawals1939/miniconda3/lib/nltk_data', '/usr/share/nltk_data', '/usr/local/share/nltk_data', '/usr/lib/nltk_data', '/usr/local/lib/nltk_data', '/scratch/Amit_Pandey/nltk_data']

# %%
## To run as batch job


#imports:

# file imports

import numpy as np
import matplotlib.pyplot as plt
import gensim
import gensim.downloader
import os
from scipy.optimize import linprog
import nltk
from collections import defaultdict
from gensim.models import KeyedVectors
import sklearn
import scipy
import time
from multiprocessing import Pool
from nltk.corpus import stopwords
import json
from multiprocessing import Pool
import time
import pickle
from gensim import models

#nltk.download('stopwords')
#nltk.download('punkt')
# nltk.download('wordnet')

print("code started and imports done \n")


def sentence_preprocess(embed_dict, sentence,lowercase = 1, strip_punctuation = 1,  remove_stopwords = 1,removedigit = 1):
    ''' 1 : True, 0 : False : Lowercase, Strip puncutation, Remove Stopwords, removedigit'''

    stop_words = list(stopwords.words('english'))

    if lowercase == 1:
        sentence = sentence.lower()

    sentence_words = nltk.word_tokenize(sentence)

    if strip_punctuation == 1 and removedigit == 1:
        sentence_words = [word for word in sentence_words if word.isalpha()] 
        


    if remove_stopwords == 1:
        sentence_words = [word for word in sentence_words if not word in stop_words]
    
    ## to remove those words which are not in the embeddings that we have.
    
    sentence_words = [word for word in sentence_words if word in embed_dict.keys()]



    return sentence_words




embeddingtype = None
embd_model = None



## to load from embedding text files:
## have used this to load glove vectors and not word2vec

def load_glove(embeddingtype):
    
    if embeddingtype == 3:
        i = 300
        
        a_file = open("/scratch/Amit_Pandey/wmd_lite/files/reduced_glove_embedding_300.json", "r")
        output = json.load(a_file)
        print(len(output.keys()))
        a_file.close()
        
        embeddings_dict = output
        
    if embeddingtype == 4:
        i = 200
    if embeddingtype == 5:
        i = 100
    if embeddingtype == 6:
        i = 50
    
    
#     embeddings_dict = defaultdict(lambda:np.zeros(i)) 
#     # defaultdict to take care of OOV words.
    
#     with open(f"../files/glove.6B.{i}d.txt",'r') as f:
#         for line in f:
#             values = line.split()
#             word = values[0]
#             vector = np.asarray(values[1:], "float32")
#             embeddings_dict[word] = vector
        
    return embeddings_dict



def embeddings_setup(newembeddingtype):
    
    
    global embeddingtype
    global embd_model
    
    
    '''to avoid loading all the embeddings in the memory.'''
    
    ''''## Note : we are finding the embd matrix two times, ie once for each sentence in
        ## the pair of sentences.
        ## so this happens that embedding type is changed when find_embmatrix is called
        ## by the first sentence.
        The above line doesnt matter now as we not calling find_embmatrix , instead we setting up.
    '''
        
        
        
    if ( embeddingtype != newembeddingtype):
        #print("embdtype  entered :", embeddingtype != newembtype,"\n")
        #print("embd_model type changed to :", type(embd_model),"\n" )
        
        embeddingtype = newembeddingtype
        
        #embd_model = embeddings_setup(embeddingtype) #adictionary
        
        #print("embd_model type changed to :", type(embd_model),"\n" )
        #to make sure that we don't download the embeddings again and again,
        # we will check if the embedding type is same as the old one
        # and update global embd_model, vrna next time vo use hi nhi ho payega.
    
    
    
    
    
    if embeddingtype == 1:
        
        ## To load from scratch:
        
        w = models.KeyedVectors.load_word2vec_format(
        '/scratch/Amit_Pandey/gensim-data/word2vec-google-news-300/GoogleNews-vectors-negative300.bin', binary=True)
        
        embedding = w
        
        #embedding = KeyedVectors.load('google300w2v.kv', mmap='r')
        ## This will be slower but will prevent kernel from crashing.
        
        ## comment the above line and uncomment this if you have sufficient RAM:
        
        #w2v_emb = gensim.downloader.load('word2vec-google-news-300')
        
    if embeddingtype == 2:
        print('Normalised word2vec not loaded, will get it soon')
        embedding = None
    
    if embeddingtype in (3,4,5,6):
        embedding = load_glove(embeddingtype)
        
    
    embd_model = embedding
    
    
        
def find_embdMatrix(sentence):
    global embeddingtype
    global embd_model
    #print(" global embedding type being passed is :", embeddingtype,"\n")
    #print("embedding type received by the find emb matrix is :", newembtype,"\n")
    #print("embd model type is :", type(embd_model),"\n")
    
    sent_mtx = []
    
    
    ##commented lines moved to embedding setup.
    
#     ''''## Note : we are finding the embd matrix two times, ie once for each sentence in
#     ## the pair of sentences.
#     ## so this happens that embedding type is changed when find_embmatrix is called
#     ## by the first sentence
#     '''
#     if ( embeddingtype != newembtype):
#         print("if embdtype part entered :", embeddingtype != newembtype,"\n")
        
#         embeddingtype = newembtype
#         embd_model = embeddings_setup(embeddingtype) #adictionary
        
#         print("embd_model type changed to :", type(embd_model),"\n" )
#     #to make sure that we don't download the embeddings again and again,
#     # we will check if the embedding type is same as the old one
#     # and update global embd_model, vrna next time vo use hi nhi ho payega.
    
    #print("embd_model type changed to :", type(embd_model),"\n" )
    for word in sentence:
        word_emb = embd_model[word]
        sent_mtx.append(word_emb)
    
    sent_mtx = np.array(sent_mtx).reshape(len(sentence),-1)

    return sent_mtx




def wasserstein_distance(pi, qj, D, cost = 'min'):
        """Find Wasserstein distance through linear programming
        p.shape=[m], q.shape=[n], D.shape=[m, n]
    
        suppose doc1 has m words and doc2 has n words, then an mxn array would be formed, 
        having distance of each word in doc1 to that of doc2.
    
    
    
        p.sum()=1, q.sum()=1, p∈[0,1], q∈[0,1]
        """
        A_eq = [] # a list which will later be converted to array after appending.
        for i in range(len(pi)): # len = number of words.
            A = np.zeros_like(D) # a 2d array made with the shape of D.  
            A[i, :] = 1 
            #print("Dshape, len pi till here :",D.shape,len(pi),"\n")
            
            # to make summation over "i" of Tij = pi, ie total / sum of outflow
            ## from one word is equal to its pi (normalized bag of word/ frequency/density)
            ## ex : if 2x3 D:
            ##T1,1 + T1,2 + T1,3 + 0 T2,1 + 0 T2,2 + 0 T2,3 = P1 and so on for every i,
            ## ie for each word in the doc1
            
            
            #print("A.shape", A.shape,"\n")
            A_eq.append(A.reshape(-1)) ## reshape(-1) flatens and then appending in A_eq.
            
            #print(A_eq,"Aeq\n")
            
            
            
            ## A_eq will be (m+n)x(m.n)
    
        for i in range(len(qj)):
            A = np.zeros_like(D)
            A[:, i] = 1 ## summation over "j" this time, so this time for different rows, 
            ## over a column "j" which refers to doc2, ie total incoming flow = qj density
            A_eq = list(A_eq)
            A_eq.append(A.reshape(-1))
            A_eq = np.array(A_eq)
        
        #print(A_eq.shape,A_eq)
       
        b_eq = np.concatenate([pi, qj])
        D = D.reshape(-1)
        #print("Dshape:",D.shape)
        if cost == 'max':
            D = D*(-1)
        
        result = linprog(D, A_eq=A_eq[:-1], b_eq=b_eq[:-1]) ## removing redundant to make 
        ## solution more robust.
        return np.absolute(result.fun), result.x , D.reshape((len(pi),len(qj)))  ## fun returns the final optimized value, x returns each value of xi,j that is the array

    
def relaxed_distance(pi,qj,D,cost='min'):
    
    # to find relaxed we just add the min/max cost directly using the least distance for pi to qj.
    
    # D is calculated from P to Q ie P in rows and Q in columns, To find Q to P we will transpose 
    if cost == 'min':
        p_to_q = np.dot(D.min(axis=1),pi)
        q_to_p = np.dot(D.T.min(axis=1),qj)
        
        return max(p_to_q,q_to_p)
    
    if cost == 'max':
        
        p_to_q = np.dot(D.max(axis=1),pi)
        q_to_p = np.dot(D.T.max(axis=1),qj)
        
        return min(p_to_q,q_to_p), None, D
        
        
    
    
class WMD:
    
    ''' wmd type = normal/relaxed, costtype = min/max.
    Enter Two sentence strings, cost = max if you want to try 
    max cost max flow version, embeddingtype = 1 for word2vec, 2 = normalized
    word2vec, 3 = glove300d, 4 = glove200d, 5 = glove100d 6 = glove50d'''
    
    def __init__(self,embeddingtype, wmd_type = 'normal', costtype='min'):
        
        
        self.cost = costtype
        
        self.embeddingtype = embeddingtype 
        self.wmd_type = wmd_type
        
        
        ## setting up the embeddings
        
        embeddings_setup(self.embeddingtype)
        
        
        
        
    #def word_count(self):
#         self.sent1_dic = defaultdict(int)
#         self.sent2_dic = defaultdict(int)
        
#         for word in sorted(sentence_preprocess(self.sent1)):
#             self.sent1_dic[word] += 1
            
#         for word in sorted(sentence_preprocess(self.sent2)):
#             self.sent2_dic[word] += 1
        
#         return dict(self.sent1_dic), dict(self.sent2_dic)



#     def wasserstein_distance(self, pi, qj, D):
#         """Find Wasserstein distance through linear programming
#         p.shape=[m], q.shape=[n], D.shape=[m, n]
    
#         suppose doc1 has m words and doc2 has n words, then an mxn array would be formed, 
#         having distance of each word in doc1 to that of doc2.
    
    
    
#         p.sum()=1, q.sum()=1, p∈[0,1], q∈[0,1]
#         """
#         A_eq = [] # a list which will later be converted to array after appending.
#         for i in range(len(pi)): # len = number of words.
#             A = np.zeros_like(D) # a 2d array made with the shape of D.  
#             A[i, :] = 1 
#             # to make summation over "i" of Tij = pi, ie total / sum of outflow
            ## from one word is equal to its pi (normalized bag of word/ frequency/density)
            ## ex : if 2x3 D:
            ##T1,1 + T1,2 + T1,3 + 0 T2,1 + 0 T2,2 + 0 T2,3 = P1 and so on for every i,
            ## ie for each word in the doc1
        
#             A_eq.append(A.reshape(-1)) ## reshape(-1) flatens and then appending in A_eq.
            ## A_eq will be (m+n)x(m.n)
    
#         for i in range(len(qj)):
#             A = np.zeros_like(D)
#             A[:, i] = 1 ## summation over "j" this time, so this time for different rows, 
#             ## over a column "j" which refers to doc2, ie total incoming flow = qj density
#             A_eq.append(A.reshape(-1))
#             A_eq = np.array(A_eq)
        
#         print(A_eq.shape,A_eq)
       
#         b_eq = np.concatenate([pi, qj])
#         D = D.reshape(-1)
#         if self.cost == 'max':
#             D = D*(-1)
        
#         result = linprog(D, A_eq=A_eq[:-1], b_eq=b_eq[:-1]) ## removing redundant to make 
#         ## solution more robust.
#         return result.fun, result.x  ## fun returns the final optimized value, x returns each value of xi,j that is the array

    
    def word_mover_distance(self,sentence1,sentence2):
        
        self.sent1 = sentence1
        #print(self.sent1 ,"\n")
        self.sent2 = sentence2
        #print(self.sent2 ,"\n")
        
        
        self.sent1_dic = defaultdict(int)
        self.sent2_dic = defaultdict(int)
        
        for word in sorted(sentence_preprocess(embd_model,self.sent1)): # sorted to have better
            self.sent1_dic[word] += 1 # idea of the sequence of the words. Creating BOW here
            
        for word in sorted(sentence_preprocess(embd_model,self.sent2)): #creating BOW from sorted sequence
            self.sent2_dic[word] += 1
        
        
        self.sent1_dic = dict(self.sent1_dic) # converted from default dict to dict.
        self.sent2_dic = dict(self.sent2_dic) # because following operations work on dict
        
        
        #print(self.sent1_dic ,"\n")
        #print(self.sent2_dic ,"\n")
        
        
        ## Now we will store a list/array of all the words in each sentence (in alphabetically sorted order)
        ## we will store corresponding count, and then corresponding Normalised count.
        self.sent1_words = np.array(list(self.sent1_dic.keys())) #dictionary keys converted to list than array
        self.sent1_counts = np.array(list(self.sent1_dic.values()))
        
        self.sent2_words = np.array(list(self.sent2_dic.keys()))
        self.sent2_counts = np.array(list(self.sent2_dic.values()))
        
        
        #print(self.sent1_words ,"\n")
        #print(self.sent1_counts ,"\n")
        
        #print(self.sent2_words ,"\n")
        #print(self.sent2_counts ,"\n")
        
        #dictionary values cant be converted into an array directly, hence the
        #list step.
        
        #print("embedding type being passed is :", self.embeddingtype,"\n")
        self.sent1_embmtx = find_embdMatrix(self.sent1_words)
        #print(self.sent1_embmtx.shape,"sent1emb\n")
        self.sent2_embmtx = find_embdMatrix(self.sent2_words)
        #print(self.sent2_embmtx.shape,"sent2emb\n")
        
        self.pi = self.sent1_counts/np.sum(self.sent1_counts) #NBOW step from BOW
        #print(self.pi,"self.pi\n")
        self.qj = self.sent2_counts/np.sum(self.sent2_counts)
        #print(self.qj,"self.qj\n")
        
        self.D = np.sqrt(np.square(self.sent1_embmtx[:, None] - self.sent2_embmtx[None, :]).sum(axis=2)) 
        #print(self.D.shape,"Dshape \n")
        ## programmers sought used mean instead of sum.
        ## scipy cdist can be used as well.
        
        if self.wmd_type == 'normal':
            return wasserstein_distance(self.pi, self.qj, self.D, self.cost)
        
        
        if self.wmd_type == 'relaxed':
            return relaxed_distance(self.pi,self.qj,self.D,self.cost)
        
print("\n FUNCTIONS DEFINITION OVER AND DATA LOADING STARTED\n")


## KNN

Train_BBCsport_sent = np.load("/scratch/Amit_Pandey/wmd_lite/files/Train_BBCsport_sent.npy")
Train_BBCsport_label = np.load("/scratch/Amit_Pandey/wmd_lite/files/Train_BBCsport_label.npy")
Test_BBCsport_sent = np.load("/scratch/Amit_Pandey/wmd_lite/files/Test_BBCsport_sent.npy")
Test_BBCsport_label = np.load("/scratch/Amit_Pandey/wmd_lite/files/Test_BBCsport_label.npy")


print("\n DATA LOADING ENDED\n")

#for i in range(5):
    #print(Test_BBCsport_label[i],"\n",Test_BBCsport_sent[i])
    

print("##################Train details:\n")

#for i in range(5):
    #print(Train_BBCsport_label[i],"\n",Train_BBCsport_sent[i])


# embeddingtype = 3
# model = WMD(embeddingtype,wmd_type = 'relaxed', costtype='max')

            
    
no_testdocs = len(Test_BBCsport_sent)
no_testlabels = len(Test_BBCsport_label)
#no_testdocs,no_testlabels



actual_category = []
predicted_category = []

    



#import time
st = time.time()
print("\n MODEL INITIALIZATION STARTED\n")
embeddingtype = 3
model = WMD(embeddingtype,wmd_type = 'normal', costtype='min')

print("\n MODEL INITIALIZATION OVER\n")

result_Dhawal = []
test_finished_Dhawal = []


def predict_Category(i):
    global result 
    global test_finished
    
    prediction_dictionary = {}
    sentence = Test_BBCsport_sent[i]
    
    distance_fromTrainset = []
    
    #for j in range (len(Train_BBCsport_sent)):
    for j in range (10): #number of train
        ## Find totalcost ie distance between sentence passed from test set to each sentence 
        ## in training set. and then append in the list.
        
        #print(sentence)
        #print(Train_BBCsport_sent[i])
        
        print(f"\nTrain{j}")
        
        Totalcost, Tcoeff, Distancematx = model.word_mover_distance(sentence,Train_BBCsport_sent[j])
        print(f" distance btwn test{i} and train{j} :", Totalcost,"\n")
        #print(Totalcost)
        distance_fromTrainset.append(Totalcost)
        
    distance_fromTrainset = np.array(distance_fromTrainset)
    #print('distance from train set array:',distance_fromTrainset)
    
    arr1indx = distance_fromTrainset.argsort()
    print("index of distance in increasing order is:", arr1indx, "\n")
    
    #print("Distance and label sorted from test set",distance_fromTrainset[arr1indx[::1]], "\n",Train_BBCsport_label[arr1indx[::1]],"\n","Sentences: \n",Train_BBCsport_sent[arr1indx[::1]]) 
    
    
    ## Taking for different values of K
    
    #k = 5
    sorted_distance_fromTrainset_k5 = distance_fromTrainset[arr1indx[::1]][:5]
    sorted_labels_k5 = Train_BBCsport_label[arr1indx[::1]][:5]
    
    predicted_cat_k5 = scipy.stats.mode(sorted_labels_k5)[0]
    #print("pred 5",predicted_cat_k5)
   

    #k = 7
    sorted_distance_fromTrainset_k7 = distance_fromTrainset[arr1indx[::1]][:7]
    sorted_labels_k7 = Train_BBCsport_label[arr1indx[::1]][:7]
    
    predicted_cat_k7 = scipy.stats.mode(sorted_labels_k7)[0]
    #print("pred 7",predicted_cat_k7)

    #k = 11
    sorted_distance_fromTrainset_k11 = distance_fromTrainset[arr1indx[::1]][:11]
    sorted_labels_k11 = Train_BBCsport_label[arr1indx[::1]][:11]
    
    predicted_cat_k11 = scipy.stats.mode(sorted_labels_k11)[0]
    #print("pred 11",predicted_cat_k11)

    #k = 15
    sorted_distance_fromTrainset_k15 = distance_fromTrainset[arr1indx[::1]][:15]
    sorted_labels_k15 = Train_BBCsport_label[arr1indx[::1]][:15]
    
    predicted_cat_k15 = scipy.stats.mode(sorted_labels_k15)[0]
    #print("pred 15",predicted_cat_k15)

    #k = 21
    sorted_distance_fromTrainset_k21 = distance_fromTrainset[arr1indx[::1]][:21]
    sorted_labels_k21 = Train_BBCsport_label[arr1indx[::1]][:21]
    
    predicted_cat_k21 = scipy.stats.mode(sorted_labels_k21)[0]
    #print("pred 21",predicted_cat_k21)


    #print(sorted_distance_fromTrainset,sorted_labels)
    prediction_dictionary[i] = [Test_BBCsport_label[i],
                                arr1indx[:30].tolist(),
                                Train_BBCsport_label[arr1indx[::1]][:30].tolist(),
                                distance_fromTrainset[arr1indx[::1]][:30].tolist(),
                                [predicted_cat_k5.tolist(),predicted_cat_k7.tolist(), predicted_cat_k11.tolist(),predicted_cat_k15.tolist(),
                                 predicted_cat_k21.tolist()]]
    
    
    result_Dhawal.append(prediction_dictionary)
    test_finished_Dhawal.append(i)
    
    
    with open('../results/result_Dhawal.pickle', 'wb') as handle:
        pickle.dump(result_Dhawal, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
    with open('../results/test_finished_Dhawal.pickle', 'wb') as handle:
        pickle.dump(test_finished_Dhawal, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
    
    
    
    
    #return np.array([predicted_cat_k5,predicted_cat_k7,predicted_cat_k11,predicted_cat_k15,predicted_cat_k21])   
        
    
    
    
no_testdocs = len(Test_BBCsport_sent)
no_testlabels = len(Test_BBCsport_label)
#no_testdocs,no_testlabels



actual_categories = []
predicted_categories_list = []
for i in range (50,70): # number of test
    print(f" \n ################### Test{i} #############","\n")
    predict_Category(i)
    
    #actual_categories.append(Test_BBCsport_label[i]) 
    #pred_category = predict_Category(Test_BBCsport_sent[i])
    #print(pred_category)
    #predicted_categories_list.append(pred_category)
    

et = time.time() 

print("time taken:",et-st)
# Out:
# code started and imports done
#
#
#  FUNCTIONS DEFINITION OVER AND DATA LOADING STARTED
#
#
#  DATA LOADING ENDED
#
# ##################Train details:
#
#
#  MODEL INITIALIZATION STARTED
#
# 12392
#
#  MODEL INITIALIZATION OVER
#
#
#  ################### Test50 #############
#
#
# Train0
#  distance btwn test50 and train0 : 6.768940438075009
#
#
# Train1
#  distance btwn test50 and train1 : 6.69551759482227
#
#
# Train2
#  distance btwn test50 and train2 : 6.7041507207270765
#
#
# Train3
#  distance btwn test50 and train3 : 6.042794495978872
#
#
# Train4
#  distance btwn test50 and train4 : 6.114087225675572
#
#
# Train5
#  distance btwn test50 and train5 : 6.3291091999106825
#
#
# Train6
#  distance btwn test50 and train6 : 5.757876794123235
#
#
# Train7
#  distance btwn test50 and train7 : 5.946441557872616
#
#
# Train8
#  distance btwn test50 and train8 : 6.631840486740563
#
#
# Train9
#  distance btwn test50 and train9 : 5.963743115386338
#
# index of distance in increasing order is: [6 7 9 3 4 5 8 1 2 0]
#
#
#  ################### Test51 #############
#
#
# Train0
#  distance btwn test51 and train0 : 6.549556396994637
#
#
# Train1
#  distance btwn test51 and train1 : 7.077755459229516
#
#
# Train2
#  distance btwn test51 and train2 : 6.797712506153514
#
#
# Train3
#  distance btwn test51 and train3 : 6.7935207312186945
#
#
# Train4
#  distance btwn test51 and train4 : 7.026490432260358
#
#
# Train5
#  distance btwn test51 and train5 : 6.771355400971726
#
#
# Train6
#  distance btwn test51 and train6 : 6.8218136025871425
#
#
# Train7
#  distance btwn test51 and train7 : 6.1965266676883175
#
#
# Train8
#  distance btwn test51 and train8 : 7.10981798620199
#
#
# Train9
#  distance btwn test51 and train9 : 6.111266482563498
#
# index of distance in increasing order is: [9 7 0 5 3 2 6 4 1 8]
#
#
#  ################### Test52 #############
#
#
# Train0
#  distance btwn test52 and train0 : 6.8703160059847885
#
#
# Train1
#  distance btwn test52 and train1 : 6.658876164205236
#
#
# Train2
#  distance btwn test52 and train2 : 6.4232351187618395
#
#
# Train3
#  distance btwn test52 and train3 : 5.970929743875075
#
#
# Train4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7812/3323566333.py in <module>
#     592 for i in range (50,70): # number of test
#     593     print(f" \n ################### Test{i} #############","\n")
# --> 594     predict_Category(i)
#     595
#     596     #actual_categories.append(Test_BBCsport_label[i])
#
# /tmp/ipykernel_7812/3323566333.py in predict_Category(i)
#     501         print(f"\nTrain{j}")
#     502
# --> 503         Totalcost, Tcoeff, Distancematx = model.word_mover_distance(sentence,Train_BBCsport_sent[j])
#     504         print(f" distance btwn test{i} and train{j} :", Totalcost,"\n")
#     505         #print(Totalcost)
#
# /tmp/ipykernel_7812/3323566333.py in word_mover_distance(self, sentence1, sentence2)
#     423
#     424         if self.wmd_type == 'normal':
# --> 425             return wasserstein_distance(self.pi, self.qj, self.D, self.cost)
#     426
#     427
#
# /tmp/ipykernel_7812/3323566333.py in wasserstein_distance(pi, qj, D, cost)
#     256             D = D*(-1)
#     257
# --> 258         result = linprog(D, A_eq=A_eq[:-1], b_eq=b_eq[:-1]) ## removing redundant to make
#     259         ## solution more robust.
#     260         return np.absolute(result.fun), result.x , D.reshape((len(pi),len(qj)))  ## fun returns the final optimized value, x returns each value of xi,j that is the array
#
# ~/miniconda3/lib/python3.8/site-packages/scipy/optimize/_linprog.py in linprog(c, A_ub, b_ub, A_eq, b_eq, bounds, method, callback, options, x0)
#     639                 postsolve_args=postsolve_args, **solver_options)
#     640         elif meth == 'interior-point':
# --> 641             x, status, message, iteration = _linprog_ip(
#     642                 c, c0=c0, A=A, b=b, callback=callback,
#     643                 postsolve_args=postsolve_args, **solver_options)
#
# ~/miniconda3/lib/python3.8/site-packages/scipy/optimize/_linprog_ip.py in _linprog_ip(c, c0, A, b, callback, postsolve_args, maxiter, tol, disp, alpha0, beta, sparse, lstsq, sym_pos, cholesky, pc, ip, permc_spec, **unknown_options)
#    1117     cholesky = cholesky or (cholesky is None and sym_pos and not lstsq)
#    1118
# -> 1119     x, status, message, iteration = _ip_hsd(A, b, c, c0, alpha0, beta,
#    1120                                             maxiter, disp, tol, sparse,
#    1121                                             lstsq, sym_pos, cholesky,
#
# ~/miniconda3/lib/python3.8/site-packages/scipy/optimize/_linprog_ip.py in _ip_hsd(A, b, c, c0, alpha0, beta, maxiter, disp, tol, sparse, lstsq, sym_pos, cholesky, pc, ip, permc_spec, callback, postsolve_args)
#     748         try:
#     749             # Solve [4] 8.6 and 8.7/8.13/8.23
# --> 750             d_x, d_y, d_z, d_tau, d_kappa = _get_delta(
#     751                 A, b, c, x, y, z, tau, kappa, gamma, eta,
#     752                 sparse, lstsq, sym_pos, cholesky, pc, ip, permc_spec)
#
# ~/miniconda3/lib/python3.8/site-packages/scipy/optimize/_linprog_ip.py in _get_delta(A, b, c, x, y, z, tau, kappa, gamma, eta, sparse, lstsq, sym_pos, cholesky, pc, ip, permc_spec)
#     212         M = A.dot(sps.diags(Dinv, 0, format="csc").dot(A.T))
#     213     else:
# --> 214         M = A.dot(Dinv.reshape(-1, 1) * A.T)
#     215     solve = _get_solver(M, sparse, lstsq, sym_pos, cholesky, permc_spec)
#     216
#
# KeyboardInterrupt:

# %%
os.listdir("../results/result_Dhawal.pickle")
# Out:
# ['test_finished_Dhawal.pickle', 'result_Dhawal.pickle', 'test_result.pickle']

# %%
import pickle
with open('../results/result_Dhawal.pickle', 'rb') as handle:
    result = pickle.load(handle)
    
    
result
# Out:
# [{50: ['athletics',
#    [254,
#     349,
#     344,
#     124,
#     52,
#     206,
#     274,
#     311,
#     111,
#     346,
#     36,
#     153,
#     75,
#     40,
#     387,
#     382,
#     94,
#     288,
#     199,
#     214,
#     152,
#     462,
#     395,
#     23,
#     143,
#     6,
#     511,
#     182,
#     207,
#     491],
#    ['athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'tennis',
#     'athletics',
#     'athletics',
#     'athletics',
#     'tennis',
#     'athletics',
#     'rugby',
#     'athletics',
#     'football',
#     'football',
#     'athletics',
#     'tennis',
#     'football',
#     'athletics',
#     'athletics',
#     'football',
#     'athletics',
#     'athletics',
#     'rugby'],
#    [4.88089273560052,
#     5.046372810888167,
#     5.062608754503342,
#     5.125022142459167,
#     5.147722303770574,
#     5.281085998053716,
#     5.281085998053716,
#     5.369639451146329,
#     5.420701191589533,
#     5.476841041036129,
#     5.476841041036129,
#     5.492626715071116,
#     5.492676657112389,
#     5.502252262674703,
#     5.507822513356765,
#     5.516241450418412,
#     5.597230997120146,
#     5.635001724498868,
#     5.691373959458742,
#     5.695764377289779,
#     5.6997566367313555,
#     5.704915869716889,
#     5.72366707327187,
#     5.750427764556319,
#     5.752229722689242,
#     5.757876794123235,
#     5.764968332555793,
#     5.776476774574961,
#     5.777052445645872,
#     5.7940419991978676],
#    [['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics']]]},
#  {51: ['football',
#    [235,
#     39,
#     435,
#     299,
#     41,
#     9,
#     121,
#     507,
#     30,
#     7,
#     478,
#     448,
#     213,
#     492,
#     315,
#     239,
#     27,
#     388,
#     87,
#     283,
#     318,
#     19,
#     508,
#     506,
#     280,
#     357,
#     466,
#     289,
#     360,
#     97],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football'],
#    [5.738305935432875,
#     5.7608261057587775,
#     5.7608261057587775,
#     6.063887741988935,
#     6.072349621947897,
#     6.111266482563498,
#     6.124708178042402,
#     6.132529889925499,
#     6.162170247647198,
#     6.1965266676883175,
#     6.20214742380087,
#     6.2133358670651155,
#     6.220107052625703,
#     6.229026617670673,
#     6.2308366241059066,
#     6.258511695938049,
#     6.281634310342582,
#     6.302417442493409,
#     6.311563936842633,
#     6.331072609257812,
#     6.336784715684165,
#     6.3393588443382,
#     6.343060502986049,
#     6.348261035345539,
#     6.357870809010983,
#     6.359439415269435,
#     6.363016345570095,
#     6.364159551999129,
#     6.365588158084524,
#     6.372433454906858],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {52: ['athletics',
#    [51,
#     353,
#     387,
#     440,
#     124,
#     505,
#     152,
#     111,
#     6,
#     415,
#     40,
#     334,
#     179,
#     27,
#     94,
#     75,
#     402,
#     327,
#     79,
#     361,
#     133,
#     467,
#     409,
#     314,
#     326,
#     88,
#     270,
#     359,
#     434,
#     475],
#    ['athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'tennis',
#     'football',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'cricket',
#     'football',
#     'football',
#     'athletics',
#     'athletics',
#     'football',
#     'athletics',
#     'football',
#     'athletics',
#     'football',
#     'football',
#     'rugby',
#     'cricket',
#     'tennis',
#     'football',
#     'rugby',
#     'tennis',
#     'tennis',
#     'tennis'],
#    [4.9434779933734,
#     4.965094943547878,
#     4.967438058898666,
#     5.021442166529733,
#     5.038201995537724,
#     5.173969005808882,
#     5.2169277413894,
#     5.278132079897726,
#     5.294619704701769,
#     5.334006028613799,
#     5.338224968864975,
#     5.3485025983556636,
#     5.3635461571105125,
#     5.366979538951366,
#     5.380680620494486,
#     5.393604126988606,
#     5.399094077291552,
#     5.40251449039037,
#     5.45043409928509,
#     5.4520739655814765,
#     5.476216663283921,
#     5.478666655764192,
#     5.48901859498131,
#     5.506258635774106,
#     5.521539894056982,
#     5.523639883233907,
#     5.523683422267189,
#     5.538848324553596,
#     5.5502158036473155,
#     5.551946440362276],
#    [['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics']]]},
#  {53: ['football',
#    [175,
#     367,
#     343,
#     166,
#     13,
#     248,
#     148,
#     403,
#     151,
#     411,
#     31,
#     247,
#     478,
#     69,
#     217,
#     121,
#     249,
#     399,
#     9,
#     492,
#     414,
#     506,
#     126,
#     17,
#     318,
#     214,
#     461,
#     388,
#     27,
#     152],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football'],
#    [5.553680989589203,
#     5.554012043978805,
#     5.7837444908732465,
#     5.811124836583136,
#     5.944342916182763,
#     5.952165191891326,
#     5.983190363983126,
#     6.005757339569986,
#     6.005757339569986,
#     6.03887953684794,
#     6.056111469396973,
#     6.083214853156211,
#     6.103847668157874,
#     6.1257716344293,
#     6.1429997552290265,
#     6.1669578140306385,
#     6.193562781352482,
#     6.218474965711267,
#     6.232095279720797,
#     6.236592145600021,
#     6.24378128052423,
#     6.264393637734124,
#     6.281962551682369,
#     6.287577611471994,
#     6.3115588573817485,
#     6.31656387228562,
#     6.3176267090525915,
#     6.3215091568293795,
#     6.325588344114021,
#     6.3271531170869055],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {54: ['football',
#    [121,
#     380,
#     492,
#     152,
#     203,
#     283,
#     413,
#     27,
#     367,
#     412,
#     388,
#     447,
#     169,
#     80,
#     510,
#     310,
#     291,
#     319,
#     135,
#     478,
#     315,
#     466,
#     323,
#     19,
#     179,
#     243,
#     402,
#     244,
#     474,
#     148],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football'],
#    [5.126096171401034,
#     5.161856455159133,
#     5.1638255029894005,
#     5.281021673463524,
#     5.325265091976194,
#     5.356693270609623,
#     5.402674473365621,
#     5.403194934164587,
#     5.428389381967646,
#     5.429368822333496,
#     5.491919039195686,
#     5.503565299080261,
#     5.51241190592108,
#     5.520106100297509,
#     5.528376838149732,
#     5.529545281026314,
#     5.543010433215922,
#     5.575175222327267,
#     5.582349361965421,
#     5.590125077242918,
#     5.608231618150213,
#     5.616805421199693,
#     5.617383183451926,
#     5.619974439886754,
#     5.625828055683746,
#     5.640218112164034,
#     5.65181248167429,
#     5.662713384061046,
#     5.6630776749640335,
#     5.663569380600266],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {55: ['rugby',
#    [385,
#     152,
#     320,
#     402,
#     335,
#     504,
#     492,
#     139,
#     511,
#     121,
#     88,
#     97,
#     103,
#     477,
#     80,
#     107,
#     353,
#     179,
#     296,
#     505,
#     293,
#     169,
#     487,
#     379,
#     74,
#     283,
#     79,
#     187,
#     108,
#     191],
#    ['rugby',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'tennis',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'athletics',
#     'football',
#     'rugby',
#     'tennis',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'rugby'],
#    [5.053961974329786,
#     5.089521356623447,
#     5.138833816269861,
#     5.141285386498947,
#     5.157141591138312,
#     5.184022776789634,
#     5.191227050145669,
#     5.197052402791283,
#     5.208826630657153,
#     5.2235202160541006,
#     5.225371248636308,
#     5.240493989137715,
#     5.245796015932378,
#     5.248624024943327,
#     5.279790650860523,
#     5.296318928270945,
#     5.301658048014817,
#     5.303578630581433,
#     5.314418679210506,
#     5.316773114338396,
#     5.3204765446221955,
#     5.331587288092346,
#     5.339175314386583,
#     5.344570591995202,
#     5.352928551852703,
#     5.35314047455547,
#     5.357907631296065,
#     5.363038396252472,
#     5.364390901859958,
#     5.364579151675711],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {56: ['tennis',
#    [59,
#     495,
#     211,
#     326,
#     332,
#     503,
#     429,
#     174,
#     449,
#     427,
#     324,
#     205,
#     269,
#     359,
#     348,
#     89,
#     389,
#     98,
#     404,
#     463,
#     172,
#     304,
#     392,
#     376,
#     301,
#     104,
#     216,
#     209,
#     101,
#     408],
#    ['tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis'],
#    [5.0166726344345784,
#     5.278014347111988,
#     5.298853573865042,
#     5.518660801208749,
#     5.52473984266372,
#     5.60717403825276,
#     5.625412821615773,
#     5.650473633898836,
#     5.679110655383742,
#     5.68111980319804,
#     5.698806034577539,
#     5.722188029852396,
#     5.759851654883686,
#     5.778039253185785,
#     5.830323345276248,
#     5.839924730142461,
#     5.86803275652969,
#     5.883014452296228,
#     5.9465541872535645,
#     5.980306420468006,
#     5.982364242225256,
#     5.986181751735897,
#     5.986187530455696,
#     5.987941612242389,
#     5.991176216296784,
#     5.997802336077356,
#     5.997830376732142,
#     6.006354905456395,
#     6.007536232197397,
#     6.009186398477542],
#    [['tennis'], ['tennis'], ['tennis'], ['tennis'], ['tennis']]]},
#  {57: ['athletics',
#    [415,
#     182,
#     339,
#     199,
#     111,
#     124,
#     40,
#     387,
#     94,
#     509,
#     349,
#     344,
#     353,
#     51,
#     346,
#     36,
#     254,
#     75,
#     6,
#     382,
#     207,
#     143,
#     384,
#     27,
#     152,
#     361,
#     153,
#     311,
#     288,
#     440],
#    ['athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'tennis',
#     'athletics',
#     'athletics',
#     'athletics',
#     'football',
#     'football',
#     'athletics',
#     'tennis',
#     'athletics',
#     'rugby',
#     'athletics'],
#    [5.071634447143179,
#     5.1389979966306925,
#     5.196387789529787,
#     5.243694900847887,
#     5.248897289419693,
#     5.285907541327394,
#     5.403464104616349,
#     5.42343021950693,
#     5.446622994998096,
#     5.470811288785637,
#     5.481748527779559,
#     5.483180078140253,
#     5.543590087641584,
#     5.59268323883947,
#     5.597672239534079,
#     5.597672239534079,
#     5.679500537045703,
#     5.70601669020077,
#     5.726880742636623,
#     5.731017446193435,
#     5.737865296858681,
#     5.743351639131447,
#     5.758815738279447,
#     5.777265613053085,
#     5.791141124609333,
#     5.802120458594831,
#     5.8112039492450185,
#     5.819315963199086,
#     5.822436561331658,
#     5.826816146912072],
#    [['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics']]]},
#  {58: ['cricket',
#    [122,
#     499,
#     398,
#     287,
#     350,
#     8,
#     418,
#     308,
#     316,
#     157,
#     454,
#     457,
#     12,
#     302,
#     110,
#     84,
#     219,
#     183,
#     184,
#     452,
#     314,
#     483,
#     106,
#     470,
#     161,
#     439,
#     230,
#     383,
#     170,
#     215],
#    ['cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket'],
#    [5.30645263801284,
#     5.399445084810449,
#     5.401695630996755,
#     5.4052873795370235,
#     5.40942718065688,
#     5.4216940132662685,
#     5.430762781938206,
#     5.46792942905803,
#     5.5433847700832395,
#     5.547632506481128,
#     5.599573061132366,
#     5.629969184165063,
#     5.632940249832484,
#     5.635302409998703,
#     5.727135461801974,
#     5.7824995839474695,
#     5.793573945828191,
#     5.796461727488487,
#     5.821929030552999,
#     5.829301056139478,
#     5.837304243432662,
#     5.844859894117,
#     5.850632684713102,
#     5.855756770457806,
#     5.868725006397257,
#     5.93963831827674,
#     5.995354284969234,
#     5.9972230211543085,
#     6.008603322866013,
#     6.017167208239027],
#    [['cricket'], ['cricket'], ['cricket'], ['cricket'], ['cricket']]]},
#  {59: ['cricket',
#    [314,
#     184,
#     457,
#     32,
#     183,
#     103,
#     442,
#     152,
#     154,
#     477,
#     267,
#     106,
#     215,
#     504,
#     28,
#     107,
#     470,
#     204,
#     288,
#     385,
#     114,
#     388,
#     178,
#     24,
#     511,
#     485,
#     433,
#     320,
#     54,
#     64],
#    ['cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'rugby',
#     'cricket',
#     'football',
#     'cricket',
#     'rugby',
#     'cricket',
#     'cricket',
#     'cricket',
#     'rugby',
#     'cricket',
#     'rugby',
#     'cricket',
#     'cricket',
#     'rugby',
#     'rugby',
#     'cricket',
#     'football',
#     'cricket',
#     'cricket',
#     'football',
#     'football',
#     'cricket',
#     'football',
#     'rugby',
#     'rugby'],
#    [4.724826193506269,
#     4.772553853290626,
#     4.8674775038707345,
#     4.891265392045506,
#     4.941390606352333,
#     4.949747689358304,
#     4.9657136478345,
#     5.002114138610854,
#     5.029878705073211,
#     5.060586671063895,
#     5.087492679197894,
#     5.122572704399649,
#     5.139870827368531,
#     5.154876902308732,
#     5.164629924293083,
#     5.18117483354712,
#     5.187026566126021,
#     5.192338604467988,
#     5.197907964861111,
#     5.198207871236945,
#     5.208217960557946,
#     5.209362649485828,
#     5.210909488676808,
#     5.255558729986216,
#     5.26109692130952,
#     5.266101608459813,
#     5.269534045816747,
#     5.280632124285308,
#     5.2908345753739345,
#     5.295556072361971],
#    [['cricket'], ['cricket'], ['cricket'], ['cricket'], ['cricket']]]},
#  {60: ['tennis',
#    [89,
#     489,
#     503,
#     211,
#     59,
#     495,
#     304,
#     449,
#     332,
#     393,
#     172,
#     326,
#     174,
#     382,
#     209,
#     359,
#     104,
#     376,
#     451,
#     427,
#     101,
#     389,
#     127,
#     205,
#     306,
#     408,
#     272,
#     98,
#     434,
#     216],
#    ['tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis'],
#    [4.667941763946854,
#     5.128952275630054,
#     5.232678207160744,
#     5.252839211500531,
#     5.271707752018206,
#     5.388075586576364,
#     5.4213405962348045,
#     5.4225018233752404,
#     5.438816344766394,
#     5.44167634034218,
#     5.474442579197203,
#     5.4862318773937,
#     5.488236558352865,
#     5.495431963171764,
#     5.530671190252221,
#     5.534290631985781,
#     5.551557904091651,
#     5.553171091191778,
#     5.5670592779425,
#     5.596650377170151,
#     5.59764282563786,
#     5.632781478752329,
#     5.63796858998281,
#     5.646389187755562,
#     5.671225067690484,
#     5.71413638620874,
#     5.752765241482223,
#     5.7554558904315,
#     5.759579193297938,
#     5.788438624433091],
#    [['tennis'], ['tennis'], ['tennis'], ['tennis'], ['tennis']]]},
#  {61: ['rugby',
#    [155,
#     313,
#     55,
#     26,
#     370,
#     259,
#     340,
#     159,
#     132,
#     446,
#     14,
#     64,
#     336,
#     152,
#     103,
#     258,
#     320,
#     228,
#     180,
#     175,
#     471,
#     491,
#     465,
#     293,
#     21,
#     43,
#     335,
#     338,
#     18,
#     497],
#    ['rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby'],
#    [5.267910660463187,
#     6.011491389720277,
#     6.298856857958297,
#     6.304580157932195,
#     6.552498919887461,
#     6.656810003501618,
#     6.668836851022332,
#     6.71519458115511,
#     6.762413775415994,
#     6.783918327160324,
#     6.8517036804175,
#     6.885883562600906,
#     6.895353823751938,
#     6.942420394319954,
#     6.945295560693276,
#     6.954651368070838,
#     6.997351439791589,
#     7.014244333309482,
#     7.020349249224981,
#     7.0297255877489295,
#     7.04860567932683,
#     7.050464426811391,
#     7.063536677868197,
#     7.076630753623899,
#     7.0796919410749055,
#     7.0903582391480375,
#     7.095658507252493,
#     7.0957378733614895,
#     7.107558109918177,
#     7.1106242064638066],
#    [['rugby'], ['rugby'], ['rugby'], ['rugby'], ['rugby']]]},
#  {62: ['athletics',
#    [111,
#     40,
#     143,
#     254,
#     387,
#     94,
#     285,
#     58,
#     297,
#     346,
#     36,
#     462,
#     344,
#     206,
#     274,
#     349,
#     75,
#     337,
#     124,
#     52,
#     376,
#     415,
#     339,
#     199,
#     207,
#     51,
#     505,
#     362,
#     304,
#     361],
#    ['athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'tennis',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'tennis',
#     'rugby',
#     'tennis',
#     'athletics'],
#    [4.526676421107067,
#     4.565575390296523,
#     4.776436155453496,
#     5.1894558372313435,
#     5.205406895460004,
#     5.241383767980506,
#     5.242887086809641,
#     5.2450707406448664,
#     5.292251014156093,
#     5.370331157367563,
#     5.370331157367563,
#     5.446350963264096,
#     5.475172754188494,
#     5.52738024897014,
#     5.52738024897014,
#     5.535437735941924,
#     5.590379483802072,
#     5.639558359758025,
#     5.648793056534826,
#     5.69334007434939,
#     5.738925524349417,
#     5.767939666003155,
#     5.789870448328624,
#     5.816658154886154,
#     5.823612249744181,
#     5.828992861602494,
#     5.865721884905398,
#     5.871839542115256,
#     5.892255374903424,
#     5.904548317782232],
#    [['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics']]]},
#  {63: ['football',
#    [407,
#     320,
#     228,
#     152,
#     126,
#     97,
#     79,
#     485,
#     402,
#     412,
#     385,
#     103,
#     497,
#     144,
#     357,
#     139,
#     179,
#     478,
#     480,
#     413,
#     74,
#     264,
#     465,
#     27,
#     169,
#     108,
#     191,
#     335,
#     57,
#     175],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'cricket',
#     'football',
#     'tennis',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'football'],
#    [4.6399984164886945,
#     5.241676298314624,
#     5.451657822423756,
#     5.515263059648432,
#     5.536123838185007,
#     5.540939546346869,
#     5.56100916038058,
#     5.601907025268577,
#     5.650362909646317,
#     5.652204605262986,
#     5.653881865343031,
#     5.656806868355148,
#     5.660529698293099,
#     5.677899708115929,
#     5.686868519937293,
#     5.688533460128416,
#     5.6897367132373695,
#     5.69143077974358,
#     5.707619515361653,
#     5.712033736377976,
#     5.718558051867478,
#     5.731015213863605,
#     5.745503400533005,
#     5.748219048229166,
#     5.75899753532152,
#     5.761792709038742,
#     5.763671285002708,
#     5.774505535839068,
#     5.775545131824961,
#     5.775634765403692],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {64: ['tennis',
#    [434,
#     272,
#     359,
#     326,
#     101,
#     477,
#     392,
#     505,
#     304,
#     172,
#     152,
#     503,
#     408,
#     139,
#     310,
#     135,
#     382,
#     475,
#     11,
#     465,
#     427,
#     320,
#     59,
#     169,
#     179,
#     153,
#     495,
#     293,
#     174,
#     54],
#    ['tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'rugby',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'football',
#     'tennis',
#     'tennis',
#     'tennis',
#     'football',
#     'football',
#     'tennis',
#     'tennis',
#     'tennis',
#     'rugby',
#     'tennis',
#     'football',
#     'tennis',
#     'football',
#     'football',
#     'tennis',
#     'tennis',
#     'rugby',
#     'tennis',
#     'rugby'],
#    [2.77691867230946e-09,
#     4.543437319458153,
#     4.645364283182276,
#     4.884900871839429,
#     4.888009305509954,
#     5.067665950428488,
#     5.080357473165835,
#     5.105265711853716,
#     5.117669659178125,
#     5.169461852353113,
#     5.181155467004581,
#     5.185154388267354,
#     5.191537926395695,
#     5.199319697990513,
#     5.202733183586764,
#     5.240382908655095,
#     5.2493851075185685,
#     5.2738354735065505,
#     5.335904033258068,
#     5.340470645054861,
#     5.345235270211267,
#     5.354976511827379,
#     5.370532566522494,
#     5.373969667401307,
#     5.376975894666122,
#     5.377823156216081,
#     5.384276824186882,
#     5.385192942591166,
#     5.396295417910172,
#     5.397374011489729],
#    [['tennis'], ['tennis'], ['tennis'], ['tennis'], ['tennis']]]},
#  {65: ['athletics',
#    [124,
#     182,
#     349,
#     75,
#     307,
#     111,
#     505,
#     191,
#     6,
#     387,
#     97,
#     40,
#     95,
#     94,
#     152,
#     440,
#     74,
#     254,
#     385,
#     341,
#     139,
#     497,
#     477,
#     334,
#     509,
#     487,
#     392,
#     379,
#     103,
#     108],
#    ['athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'tennis',
#     'athletics',
#     'tennis',
#     'rugby',
#     'athletics',
#     'athletics',
#     'football',
#     'athletics',
#     'rugby',
#     'athletics',
#     'football',
#     'athletics',
#     'rugby',
#     'athletics',
#     'rugby',
#     'athletics',
#     'tennis',
#     'rugby',
#     'rugby',
#     'cricket',
#     'athletics',
#     'rugby',
#     'tennis',
#     'rugby',
#     'rugby',
#     'football'],
#    [5.427960908261161,
#     5.5843810858544405,
#     5.650966175451387,
#     5.706215387534922,
#     5.71284681630032,
#     5.717825466439272,
#     5.721220593854268,
#     5.721609695901748,
#     5.734111554315821,
#     5.7364456824989025,
#     5.784550504811672,
#     5.786876390914275,
#     5.790052493338056,
#     5.804813941703753,
#     5.808858085909582,
#     5.837646039923044,
#     5.842665994402178,
#     5.843087553536374,
#     5.843176914324729,
#     5.843622243547972,
#     5.843772868653144,
#     5.8444824908944994,
#     5.848075347302688,
#     5.862869911437005,
#     5.880101989521252,
#     5.884542264626736,
#     5.8868118502586535,
#     5.8878092606730785,
#     5.891178600433988,
#     5.895725794356733],
#    [['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics']]]},
#  {66: ['rugby',
#    [335,
#     66,
#     385,
#     296,
#     28,
#     62,
#     95,
#     511,
#     480,
#     88,
#     107,
#     152,
#     169,
#     64,
#     223,
#     504,
#     103,
#     74,
#     400,
#     421,
#     487,
#     379,
#     293,
#     21,
#     112,
#     510,
#     477,
#     406,
#     231,
#     464],
#    ['rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'cricket',
#     'rugby',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'cricket',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby'],
#    [5.743976706810408,
#     5.9420582685775525,
#     5.94911510015651,
#     5.95668803811734,
#     5.982499768440262,
#     6.0437942509375215,
#     6.047188354797749,
#     6.057372666787414,
#     6.064764507562539,
#     6.0745629123604,
#     6.087622949557866,
#     6.106495664514357,
#     6.117755543809294,
#     6.1185470986716535,
#     6.125185262189616,
#     6.130934788422529,
#     6.139960948111814,
#     6.1430072458946,
#     6.152785016387421,
#     6.181867329077569,
#     6.186619427144996,
#     6.190304091381121,
#     6.19811667960745,
#     6.202318332154108,
#     6.208620609204178,
#     6.216187183658004,
#     6.219984412080513,
#     6.220020552229139,
#     6.220938285204068,
#     6.2216826711002415],
#    [['rugby'], ['rugby'], ['rugby'], ['rugby'], ['rugby']]]},
#  {67: ['rugby',
#    [313,
#     26,
#     78,
#     55,
#     292,
#     426,
#     155,
#     432,
#     294,
#     14,
#     477,
#     270,
#     259,
#     54,
#     293,
#     268,
#     424,
#     45,
#     484,
#     188,
#     56,
#     198,
#     340,
#     76,
#     68,
#     252,
#     38,
#     180,
#     238,
#     137],
#    ['rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby'],
#    [4.92649725711073,
#     5.119918631566755,
#     5.122648191999671,
#     5.1369326897706165,
#     5.32055996284784,
#     5.707614664774642,
#     5.789802009300385,
#     5.881386686774225,
#     5.899831895371107,
#     5.926907713182286,
#     5.928406392225097,
#     5.996929994674589,
#     6.051582385184842,
#     6.109778554780622,
#     6.15461521282612,
#     6.176604814428805,
#     6.182768246590784,
#     6.195089850865898,
#     6.20516768600592,
#     6.206588598514997,
#     6.254949059762502,
#     6.26726162831182,
#     6.327559466425845,
#     6.332213367895097,
#     6.335344759928746,
#     6.336928933168782,
#     6.339507930757953,
#     6.346968165268805,
#     6.352613537172765,
#     6.368276109391589],
#    [['rugby'], ['rugby'], ['rugby'], ['rugby'], ['rugby']]]},
#  {68: ['cricket',
#    [271,
#     109,
#     32,
#     364,
#     314,
#     377,
#     457,
#     100,
#     428,
#     210,
#     183,
#     452,
#     161,
#     215,
#     24,
#     29,
#     178,
#     288,
#     372,
#     1,
#     493,
#     442,
#     469,
#     267,
#     8,
#     156,
#     371,
#     437,
#     352,
#     86],
#    ['cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'rugby',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'football',
#     'cricket'],
#    [5.607651151773757,
#     5.988370711740357,
#     5.992581489909193,
#     6.065705425847238,
#     6.070607261565239,
#     6.086788178554357,
#     6.167706970450646,
#     6.202214834335022,
#     6.202963458554592,
#     6.205618780620849,
#     6.208289381972833,
#     6.2131949794395975,
#     6.238431988574708,
#     6.2594176757412585,
#     6.286718478913354,
#     6.3022117040159635,
#     6.31536271986926,
#     6.328397452276672,
#     6.3317188448214425,
#     6.337544575082232,
#     6.339299039000662,
#     6.341302224377001,
#     6.3425615123032495,
#     6.345785000244492,
#     6.360533833553919,
#     6.362084027202735,
#     6.389359323469121,
#     6.392249454513898,
#     6.393274463229976,
#     6.3951511115214705],
#    [['cricket'], ['cricket'], ['cricket'], ['cricket'], ['cricket']]]},
#  {69: ['cricket',
#    [105,
#     178,
#     1,
#     156,
#     314,
#     109,
#     284,
#     210,
#     32,
#     386,
#     493,
#     469,
#     29,
#     457,
#     183,
#     100,
#     168,
#     24,
#     167,
#     504,
#     364,
#     373,
#     161,
#     267,
#     433,
#     377,
#     106,
#     33,
#     470,
#     103],
#    ['cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'rugby',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'rugby'],
#    [4.3597707718241026,
#     4.8692592349890225,
#     5.23327609431654,
#     5.311774651271492,
#     5.3121393383012006,
#     5.351099644495191,
#     5.4000802913238735,
#     5.452132454466748,
#     5.512594416406969,
#     5.57448527669837,
#     5.58987887831191,
#     5.590757962679838,
#     5.617667123719829,
#     5.624415518575358,
#     5.709838483119831,
#     5.7162644541421574,
#     5.745785016570903,
#     5.786751795779322,
#     5.81144032608603,
#     5.85474670164343,
#     5.883879929051307,
#     5.884090620157901,
#     5.886182770729036,
#     5.901052464177884,
#     5.906074388435091,
#     5.908016417699217,
#     5.909947133986253,
#     5.910438245373909,
#     5.925167451009098,
#     5.932617049530766],
#    [['cricket'], ['cricket'], ['cricket'], ['cricket'], ['cricket']]]},
#  {70: ['rugby',
#    [293,
#     163,
#     43,
#     64,
#     103,
#     270,
#     54,
#     140,
#     504,
#     281,
#     180,
#     136,
#     21,
#     288,
#     385,
#     112,
#     477,
#     74,
#     290,
#     491,
#     409,
#     487,
#     379,
#     45,
#     432,
#     152,
#     137,
#     191,
#     424,
#     187],
#    ['rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby'],
#    [5.075886115580126,
#     5.335402457866827,
#     5.368441562441697,
#     5.425691050866484,
#     5.441883738172087,
#     5.444209116186039,
#     5.463011059109774,
#     5.516248043067509,
#     5.534630054704193,
#     5.543921239177216,
#     5.544799933599626,
#     5.5498481374578885,
#     5.554454671719463,
#     5.600125344354849,
#     5.608900981629229,
#     5.613303680190787,
#     5.614933304942275,
#     5.643033834414426,
#     5.650055164433608,
#     5.654126094659275,
#     5.66366225217433,
#     5.665782464265815,
#     5.669536789377284,
#     5.6986354915163835,
#     5.707035181293504,
#     5.722532481170046,
#     5.724933398651938,
#     5.741099564378449,
#     5.746313071290444,
#     5.765970166109323],
#    [['rugby'], ['rugby'], ['rugby'], ['rugby'], ['rugby']]]},
#  {71: ['rugby',
#    [296,
#     402,
#     335,
#     187,
#     507,
#     283,
#     360,
#     388,
#     362,
#     511,
#     385,
#     169,
#     239,
#     107,
#     492,
#     343,
#     121,
#     108,
#     152,
#     74,
#     409,
#     315,
#     504,
#     320,
#     293,
#     62,
#     133,
#     467,
#     233,
#     280],
#    ['rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'football'],
#    [5.241555863133911,
#     5.28550009262468,
#     5.2920279679094175,
#     5.313950579953767,
#     5.316125870479411,
#     5.323566595122383,
#     5.38746075999956,
#     5.404712712932592,
#     5.405949903657771,
#     5.412860360067315,
#     5.435803303169051,
#     5.452874717731813,
#     5.502160614531695,
#     5.502475971380301,
#     5.510533616687068,
#     5.516042191084942,
#     5.518325232484575,
#     5.519362219298254,
#     5.524872961017893,
#     5.542785530700795,
#     5.544647510874078,
#     5.546314272787785,
#     5.548190269623935,
#     5.559584705113216,
#     5.567011714549636,
#     5.569728230845154,
#     5.5709616512474955,
#     5.5738492402682365,
#     5.574333048872202,
#     5.581106837386225],
#    [['rugby'], ['football'], ['football'], ['football'], ['football']]]},
#  {72: ['tennis',
#    [326,
#     172,
#     303,
#     171,
#     139,
#     359,
#     304,
#     505,
#     101,
#     495,
#     331,
#     153,
#     11,
#     434,
#     427,
#     475,
#     193,
#     255,
#     102,
#     395,
#     451,
#     307,
#     332,
#     376,
#     503,
#     216,
#     205,
#     272,
#     392,
#     312],
#    ['tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis'],
#    [4.784740213136427,
#     5.1012752401057915,
#     5.191216819457258,
#     5.2437978335341375,
#     5.3646895955251725,
#     5.399508796170383,
#     5.500820606358093,
#     5.511585373919947,
#     5.519876128967454,
#     5.522993517769529,
#     5.5521781340203535,
#     5.565085994511378,
#     5.5956991056354175,
#     5.6000714355206815,
#     5.609104271432698,
#     5.626179076781862,
#     5.630796526829849,
#     5.649254163049207,
#     5.649254163049207,
#     5.684678413907108,
#     5.698103770746585,
#     5.705483599477832,
#     5.710962969286561,
#     5.716949304387738,
#     5.717529652018698,
#     5.722097908441988,
#     5.750809392148994,
#     5.7523528150273116,
#     5.766053012506129,
#     5.7695603076177235],
#    [['tennis'], ['tennis'], ['tennis'], ['tennis'], ['tennis']]]},
#  {73: ['football',
#    [245,
#     416,
#     22,
#     76,
#     20,
#     238,
#     188,
#     310,
#     31,
#     42,
#     252,
#     453,
#     135,
#     19,
#     68,
#     414,
#     65,
#     97,
#     173,
#     192,
#     477,
#     456,
#     291,
#     27,
#     116,
#     179,
#     405,
#     54,
#     299,
#     9],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football'],
#    [5.4111919147016385,
#     5.873909810881306,
#     6.001104564318757,
#     6.098802607889347,
#     6.111001504215866,
#     6.136996480826474,
#     6.152184094462457,
#     6.158531139512783,
#     6.164740922526377,
#     6.184748056600154,
#     6.209823978803822,
#     6.210285310741909,
#     6.216963604375262,
#     6.220780883611473,
#     6.236171130578588,
#     6.249221922983228,
#     6.274481921571661,
#     6.276309611206949,
#     6.279318915025324,
#     6.289489450841296,
#     6.303438376109864,
#     6.31317998455274,
#     6.32552496327739,
#     6.326852563176051,
#     6.339610772861823,
#     6.340552417577422,
#     6.347982278815666,
#     6.357029115935794,
#     6.357042875754955,
#     6.368914075274793],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {74: ['football',
#    [231,
#     357,
#     179,
#     152,
#     402,
#     283,
#     315,
#     97,
#     27,
#     505,
#     305,
#     108,
#     121,
#     169,
#     474,
#     492,
#     233,
#     511,
#     512,
#     175,
#     307,
#     412,
#     88,
#     228,
#     79,
#     320,
#     507,
#     280,
#     103,
#     293],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'tennis',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'tennis',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'rugby'],
#    [5.193884231806837,
#     5.329480434519196,
#     5.36482768684764,
#     5.375934845787346,
#     5.406257338350018,
#     5.437064256884002,
#     5.459106974205159,
#     5.51083720599886,
#     5.53508780363498,
#     5.537747206032986,
#     5.545618438863384,
#     5.555336417624633,
#     5.555694613888111,
#     5.559334964726117,
#     5.5716603799062625,
#     5.5726123079035155,
#     5.5793500319907094,
#     5.5922395323514476,
#     5.595024766801773,
#     5.6026837991615395,
#     5.604159598253208,
#     5.617221902453045,
#     5.6302963650977595,
#     5.637353638413996,
#     5.649706699725403,
#     5.660879755461627,
#     5.670962225717108,
#     5.676437376756008,
#     5.679336477763833,
#     5.683498894202688],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {75: ['tennis',
#    [449,
#     451,
#     404,
#     389,
#     463,
#     301,
#     269,
#     429,
#     495,
#     332,
#     59,
#     359,
#     326,
#     304,
#     455,
#     324,
#     174,
#     382,
#     216,
#     205,
#     101,
#     98,
#     392,
#     104,
#     85,
#     408,
#     489,
#     376,
#     331,
#     434],
#    ['tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis'],
#    [1.914421299835785,
#     4.8684975351195545,
#     5.0171925128428025,
#     5.106942936248652,
#     5.1510240001883805,
#     5.375780729709829,
#     5.417944078680969,
#     5.469697670346058,
#     5.608412698888801,
#     5.654369160645365,
#     5.67886010437006,
#     5.717291944932461,
#     5.721687073842557,
#     5.737397761687655,
#     5.74900046605849,
#     5.757170496695267,
#     5.762072771174366,
#     5.767232082146286,
#     5.794601064366545,
#     5.8133665331081295,
#     5.8166853771780165,
#     5.829545528500073,
#     5.851252367449576,
#     5.8961750922478835,
#     5.905989628873464,
#     5.966038145971904,
#     5.99808788198451,
#     6.034570945480649,
#     6.045068205650128,
#     6.04626281531416],
#    [['tennis'], ['tennis'], ['tennis'], ['tennis'], ['tennis']]]},
#  {76: ['tennis',
#    [463,
#     389,
#     301,
#     216,
#     449,
#     174,
#     332,
#     205,
#     59,
#     495,
#     326,
#     324,
#     404,
#     429,
#     434,
#     101,
#     382,
#     359,
#     304,
#     98,
#     451,
#     54,
#     503,
#     331,
#     476,
#     392,
#     269,
#     272,
#     104,
#     455],
#    ['tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'rugby',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis'],
#    [0.16715557613231863,
#     4.685577186526586,
#     4.886180373424781,
#     4.943871471528633,
#     5.043899356431136,
#     5.289423682617504,
#     5.530718814584607,
#     5.561993142232728,
#     5.564290742749591,
#     5.568626738794404,
#     5.5792479348457595,
#     5.641182098455501,
#     5.666629798541695,
#     5.667375956297875,
#     5.695032998017743,
#     5.709159386761856,
#     5.70959706497258,
#     5.8189409851335006,
#     5.821975858150586,
#     5.857047533105556,
#     5.882924177476976,
#     5.894177788459402,
#     5.900195865162338,
#     5.903880356263303,
#     5.941501863006373,
#     5.9449537378583175,
#     5.959200313777377,
#     5.968680913730602,
#     6.015422358722461,
#     6.035700417449048],
#    [['tennis'], ['tennis'], ['tennis'], ['tennis'], ['tennis']]]},
#  {77: ['tennis',
#    [359,
#     101,
#     434,
#     153,
#     475,
#     304,
#     477,
#     326,
#     382,
#     172,
#     393,
#     495,
#     503,
#     331,
#     332,
#     451,
#     174,
#     449,
#     505,
#     392,
#     59,
#     121,
#     272,
#     112,
#     427,
#     376,
#     193,
#     303,
#     135,
#     389],
#    ['tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'rugby',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'football',
#     'tennis',
#     'rugby',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'football',
#     'tennis'],
#    [0.0759911638776122,
#     3.963344972083948,
#     4.645876710265209,
#     4.712085144406638,
#     4.81846609228374,
#     4.850360096088762,
#     4.851864563106016,
#     4.8546786022312425,
#     4.863624548867075,
#     4.944443385097838,
#     4.952366390973204,
#     4.973036869767905,
#     5.037854057396396,
#     5.100949675470833,
#     5.122359551661787,
#     5.141367034937808,
#     5.142126917591164,
#     5.143649308372619,
#     5.200477908523977,
#     5.255231424239852,
#     5.260382510035785,
#     5.264387064863901,
#     5.270498297051699,
#     5.280105716097784,
#     5.286121770505224,
#     5.2984545635490266,
#     5.317745022322571,
#     5.328026805882446,
#     5.336580864149961,
#     5.339558198818438],
#    [['tennis'], ['tennis'], ['tennis'], ['tennis'], ['tennis']]]},
#  {78: ['football',
#    [299,
#     9,
#     288,
#     235,
#     319,
#     343,
#     244,
#     492,
#     322,
#     214,
#     23,
#     474,
#     42,
#     239,
#     318,
#     490,
#     253,
#     367,
#     310,
#     399,
#     351,
#     431,
#     97,
#     153,
#     315,
#     13,
#     388,
#     191,
#     414,
#     169],
#    ['football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'tennis',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'tennis',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football'],
#    [5.261886470762563,
#     5.283971126705996,
#     5.747365383005059,
#     5.814844807070214,
#     5.888075682759187,
#     5.900983455528667,
#     5.930419207596965,
#     5.937170709861183,
#     5.953162790994893,
#     5.957653853367086,
#     5.963924416526604,
#     6.001872505609108,
#     6.014896036633941,
#     6.023699608016031,
#     6.0325834979515855,
#     6.033134977115905,
#     6.034331576575079,
#     6.035424062095016,
#     6.0368641749514405,
#     6.038450675446475,
#     6.0455201723833785,
#     6.052577974837257,
#     6.052678589871897,
#     6.05482023337209,
#     6.058014656758033,
#     6.0756516270923395,
#     6.08970139334928,
#     6.091091691861303,
#     6.094223288189923,
#     6.101767194657079],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {79: ['cricket',
#    [314,
#     445,
#     86,
#     452,
#     110,
#     347,
#     308,
#     298,
#     383,
#     161,
#     210,
#     183,
#     433,
#     302,
#     364,
#     109,
#     84,
#     215,
#     267,
#     230,
#     470,
#     483,
#     32,
#     184,
#     377,
#     385,
#     154,
#     24,
#     428,
#     493],
#    ['cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'rugby',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket'],
#    [4.979408655706014,
#     5.038382689285962,
#     5.0656215010812415,
#     5.239062599355943,
#     5.242262991055078,
#     5.274237630565873,
#     5.404119746926954,
#     5.445127934544606,
#     5.465345518149535,
#     5.510929799667032,
#     5.542860723813273,
#     5.557768014145804,
#     5.560870305310272,
#     5.583011791639104,
#     5.5849128954329395,
#     5.588817022880864,
#     5.603705250808468,
#     5.614052246209843,
#     5.630713111274006,
#     5.643346725294418,
#     5.653676163802677,
#     5.675747617985783,
#     5.688113034435106,
#     5.71720150013787,
#     5.733814704188098,
#     5.764432183942612,
#     5.769029970916969,
#     5.769103712661719,
#     5.771329614095339,
#     5.774937691965681],
#    [['cricket'], ['cricket'], ['cricket'], ['cricket'], ['cricket']]]},
#  {80: ['rugby',
#    [385,
#     487,
#     379,
#     288,
#     335,
#     234,
#     333,
#     504,
#     74,
#     137,
#     419,
#     95,
#     484,
#     409,
#     103,
#     270,
#     293,
#     152,
#     21,
#     402,
#     320,
#     196,
#     465,
#     187,
#     334,
#     290,
#     63,
#     32,
#     321,
#     144],
#    ['rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'cricket',
#     'rugby',
#     'rugby',
#     'cricket',
#     'rugby',
#     'cricket'],
#    [0.030573500156783964,
#     4.887163836152675,
#     4.8924309716901995,
#     4.8943905295935135,
#     4.947316934859069,
#     4.953458453229687,
#     5.002709505541071,
#     5.029339166148024,
#     5.1403928667467325,
#     5.174196288902564,
#     5.189584576480856,
#     5.194807492050899,
#     5.208663185725966,
#     5.216749186493848,
#     5.220088023846426,
#     5.230122867571605,
#     5.254382919505282,
#     5.277038143230517,
#     5.27845858593356,
#     5.279473579469556,
#     5.292143186223232,
#     5.31913651726852,
#     5.320737262705844,
#     5.325165604642512,
#     5.326439276874739,
#     5.351371803786368,
#     5.357601542026426,
#     5.3626659569453246,
#     5.378478342903416,
#     5.398005453663296],
#    [['rugby'], ['rugby'], ['rugby'], ['rugby'], ['rugby']]]},
#  {81: ['football',
#    [266,
#     236,
#     406,
#     352,
#     67,
#     231,
#     119,
#     421,
#     315,
#     464,
#     25,
#     342,
#     443,
#     97,
#     213,
#     438,
#     407,
#     32,
#     144,
#     307,
#     317,
#     334,
#     41,
#     372,
#     139,
#     310,
#     178,
#     255,
#     102,
#     264],
#    ['football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'cricket',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'cricket',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'cricket',
#     'cricket',
#     'tennis',
#     'football',
#     'cricket',
#     'football',
#     'cricket',
#     'tennis',
#     'football',
#     'cricket',
#     'tennis',
#     'tennis',
#     'football'],
#    [5.625309059771578,
#     5.684018149748992,
#     6.128980642517003,
#     6.155704650175129,
#     6.194917554093004,
#     6.219685369088844,
#     6.244842563291398,
#     6.262009572687058,
#     6.265325013263515,
#     6.2731681054401545,
#     6.286809728103373,
#     6.291967724569194,
#     6.297585820377238,
#     6.299488833630969,
#     6.30860951461867,
#     6.312787016662888,
#     6.314776594687172,
#     6.348143657400301,
#     6.350359881145825,
#     6.351845041751816,
#     6.358815489263364,
#     6.361724326845961,
#     6.364736178826886,
#     6.365245955632739,
#     6.373980129738703,
#     6.391663736094284,
#     6.3919191191178815,
#     6.392860716420378,
#     6.392860716420378,
#     6.393252746542929],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {82: ['cricket',
#    [418,
#     138,
#     350,
#     12,
#     122,
#     219,
#     398,
#     157,
#     8,
#     170,
# ...
#     'rugby',
#     'football',
#     'rugby',
#     'cricket',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'cricket',
#     'football',
#     'cricket',
#     'tennis',
#     'football',
#     'rugby',
#     'rugby',
#     'cricket'],
#    [5.303815061274715,
#     5.449862796724539,
#     5.497166368918306,
#     5.5246946002042465,
#     5.5328567626676435,
#     5.571936650244354,
#     5.5755046220193325,
#     5.578933248802138,
#     5.596885526496624,
#     5.614708014581687,
#     5.634089788038099,
#     5.641286086401131,
#     5.649886657334953,
#     5.650548916400968,
#     5.651116164842737,
#     5.6571745331645005,
#     5.669137364842513,
#     5.679721688574865,
#     5.69792227953761,
#     5.703269246996809,
#     5.70567670831493,
#     5.715002523281954,
#     5.722891509547012,
#     5.727006327237973,
#     5.7324255107936555,
#     5.740173018828785,
#     5.7402798354706155,
#     5.741500268814052,
#     5.743529142361712,
#     5.747242437830228],
#    [['cricket'], ['cricket'], ['cricket'], ['cricket'], ['cricket']]]},
#  {100: ['football',
#    [13,
#     478,
#     474,
#     248,
#     17,
#     343,
#     506,
#     318,
#     411,
#     213,
#     126,
#     69,
#     247,
#     412,
#     283,
#     413,
#     220,
#     27,
#     492,
#     148,
#     403,
#     151,
#     414,
#     57,
#     315,
#     121,
#     357,
#     42,
#     309,
#     468],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football'],
#    [4.865706786661774,
#     4.9991209761611675,
#     5.139877541442625,
#     5.198521630800354,
#     5.209115175524192,
#     5.209441789029632,
#     5.2403926332834,
#     5.274394890378591,
#     5.373745202904652,
#     5.37527620142722,
#     5.3974099827375,
#     5.462728790155783,
#     5.48208000628994,
#     5.541451666362362,
#     5.576722548610364,
#     5.586804327925402,
#     5.5998673482684,
#     5.615671223073882,
#     5.624798235227499,
#     5.658942437031064,
#     5.666302667762642,
#     5.666302667762642,
#     5.67112765414776,
#     5.686839844842462,
#     5.702094465626453,
#     5.735337268096812,
#     5.738930061134411,
#     5.741760973902927,
#     5.742268461747804,
#     5.742268461747804],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {101: ['football',
#    [136,
#     422,
#     159,
#     162,
#     130,
#     42,
#     293,
#     18,
#     103,
#     318,
#     43,
#     45,
#     431,
#     146,
#     163,
#     87,
#     486,
#     235,
#     140,
#     448,
#     270,
#     416,
#     118,
#     320,
#     299,
#     9,
#     511,
#     7,
#     409,
#     261],
#    ['rugby',
#     'football',
#     'rugby',
#     'football',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'football',
#     'rugby',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football'],
#    [6.0508032922957655,
#     6.237630519185106,
#     6.241226830801814,
#     6.289887347005469,
#     6.366485634503784,
#     6.370470766698791,
#     6.376025882217321,
#     6.398674144425831,
#     6.413609043421104,
#     6.413956831337966,
#     6.428027319989889,
#     6.43137364268598,
#     6.432091807191583,
#     6.454933330173713,
#     6.456109970709064,
#     6.464864160198572,
#     6.465940893381456,
#     6.477821334204316,
#     6.493618331518695,
#     6.50560527943988,
#     6.515747437625066,
#     6.515895958773477,
#     6.52935167662749,
#     6.529420989986951,
#     6.547373933419606,
#     6.55227751091504,
#     6.556558846127046,
#     6.575869127079485,
#     6.582741962705528,
#     6.583046551859385],
#    [['rugby'], ['rugby'], ['rugby'], ['rugby'], ['rugby']]]},
#  {102: ['football',
#    [264,
#     360,
#     412,
#     241,
#     420,
#     41,
#     97,
#     414,
#     320,
#     74,
#     510,
#     69,
#     492,
#     343,
#     152,
#     388,
#     239,
#     57,
#     42,
#     461,
#     511,
#     448,
#     169,
#     315,
#     121,
#     248,
#     149,
#     118,
#     464,
#     25],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'rugby'],
#    [5.1624711749526995,
#     5.223004200545602,
#     5.276297688335227,
#     5.312677528292365,
#     5.419620908746938,
#     5.4597730747663435,
#     5.475999170527317,
#     5.49198828751196,
#     5.504116396924218,
#     5.514694572094257,
#     5.515876751687538,
#     5.524210731233404,
#     5.543867218093459,
#     5.564214232420793,
#     5.565131739175837,
#     5.566754120424757,
#     5.569083136456921,
#     5.573407269750113,
#     5.574187035101741,
#     5.584311104544149,
#     5.592750088124358,
#     5.595233285228559,
#     5.595921803431745,
#     5.6006804107730614,
#     5.605228141486325,
#     5.606237721885324,
#     5.607033561973896,
#     5.607254614875275,
#     5.618888499537708,
#     5.6297322859263925],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {103: ['football',
#    [357,
#     128,
#     97,
#     396,
#     120,
#     39,
#     435,
#     54,
#     27,
#     7,
#     103,
#     512,
#     87,
#     179,
#     510,
#     175,
#     335,
#     485,
#     402,
#     480,
#     478,
#     169,
#     232,
#     375,
#     413,
#     320,
#     191,
#     213,
#     88,
#     152],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football'],
#    [5.659432160958714,
#     5.684336475413604,
#     5.8111264839150305,
#     5.828686670805363,
#     5.850886409245932,
#     5.8557653217324726,
#     5.8557653217324726,
#     5.856340012781937,
#     5.908646887506397,
#     5.913003223885203,
#     5.918573796251155,
#     5.939230227540067,
#     5.943546086028948,
#     5.957311441113609,
#     5.972747084888387,
#     5.983852268644317,
#     5.990792263292657,
#     5.991695379588707,
#     6.01619892095966,
#     6.022187165599095,
#     6.025979984676983,
#     6.0275941873965335,
#     6.029609400950183,
#     6.03214974456414,
#     6.038742998783345,
#     6.056107374061654,
#     6.05639769250063,
#     6.072176579673698,
#     6.07883231182272,
#     6.0808191308931185],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {104: ['tennis',
#    [427,
#     494,
#     83,
#     395,
#     449,
#     59,
#     269,
#     495,
#     451,
#     408,
#     376,
#     174,
#     332,
#     193,
#     153,
#     503,
#     195,
#     389,
#     211,
#     205,
#     489,
#     255,
#     102,
#     89,
#     359,
#     101,
#     392,
#     326,
#     490,
#     209],
#    ['tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis'],
#    [4.8508339179042705,
#     5.073598390126306,
#     5.099887919060808,
#     5.552378831377327,
#     5.6076338927248095,
#     5.61129953429385,
#     5.745775677133388,
#     5.758861431036855,
#     5.771954188488348,
#     5.8510184636780345,
#     5.908369523756072,
#     5.939435107039029,
#     5.95198835081489,
#     5.972262139783894,
#     6.024457354237342,
#     6.05040935941614,
#     6.059927957301085,
#     6.085018255409183,
#     6.08981992492286,
#     6.101556266343907,
#     6.113678792336926,
#     6.126845507546186,
#     6.126845507546186,
#     6.1314905631478975,
#     6.164050203285699,
#     6.1642117536277565,
#     6.165751902926388,
#     6.169006039010771,
#     6.178717594767855,
#     6.200428578426822],
#    [['tennis'], ['tennis'], ['tennis'], ['tennis'], ['tennis']]]},
#  {105: ['athletics',
#    [111,
#     387,
#     40,
#     124,
#     27,
#     75,
#     94,
#     353,
#     402,
#     152,
#     334,
#     505,
#     344,
#     179,
#     143,
#     440,
#     382,
#     79,
#     270,
#     169,
#     413,
#     304,
#     133,
#     467,
#     58,
#     359,
#     361,
#     349,
#     254,
#     462],
#    ['athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'football',
#     'athletics',
#     'athletics',
#     'athletics',
#     'football',
#     'football',
#     'cricket',
#     'tennis',
#     'athletics',
#     'football',
#     'athletics',
#     'athletics',
#     'tennis',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'tennis',
#     'football',
#     'football',
#     'athletics',
#     'tennis',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics'],
#    [4.522723949839904,
#     4.533725797239573,
#     4.853930779611657,
#     4.993303641291875,
#     5.125299097239472,
#     5.150007856040676,
#     5.238069087514778,
#     5.27932309300859,
#     5.306188374599571,
#     5.33147339403357,
#     5.337574579720021,
#     5.352227407215659,
#     5.38989534411628,
#     5.406139105318216,
#     5.409590169631371,
#     5.410127892158167,
#     5.417497517809388,
#     5.417849577623364,
#     5.427166402083389,
#     5.427510019836836,
#     5.4377343567208865,
#     5.4398868540844765,
#     5.467468039318155,
#     5.470277102484527,
#     5.488476273995891,
#     5.491587807690334,
#     5.500524000739183,
#     5.507888447382627,
#     5.514617693126548,
#     5.519526786964143],
#    [['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics']]]},
#  {106: ['rugby',
#    [18,
#     64,
#     140,
#     159,
#     491,
#     112,
#     103,
#     136,
#     477,
#     359,
#     293,
#     497,
#     258,
#     288,
#     43,
#     137,
#     21,
#     409,
#     465,
#     382,
#     504,
#     290,
#     496,
#     191,
#     74,
#     333,
#     180,
#     54,
#     63,
#     155],
#    ['rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'tennis',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'tennis',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby'],
#    [4.444831271188496,
#     4.737771162166734,
#     4.780145761034359,
#     5.0042337264708925,
#     5.039983561436457,
#     5.080583829899618,
#     5.080795370674511,
#     5.0935890117924,
#     5.218659185720489,
#     5.235525691601165,
#     5.236895723919478,
#     5.238918313698519,
#     5.270299544655144,
#     5.278929857361952,
#     5.284533273471605,
#     5.287154318447957,
#     5.377264953955557,
#     5.377855868456969,
#     5.3787678456050445,
#     5.37964251982447,
#     5.390131026810536,
#     5.405526523281125,
#     5.41215331793476,
#     5.434412412446737,
#     5.465595771318835,
#     5.49409230077984,
#     5.496007269310124,
#     5.5146508296308845,
#     5.526220452501336,
#     5.553232450194121],
#    [['rugby'], ['rugby'], ['rugby'], ['rugby'], ['rugby']]]},
#  {107: ['athletics',
#    [401,
#     129,
#     160,
#     111,
#     344,
#     94,
#     349,
#     61,
#     341,
#     276,
#     207,
#     251,
#     143,
#     4,
#     427,
#     462,
#     34,
#     419,
#     206,
#     274,
#     363,
#     40,
#     376,
#     304,
#     58,
#     489,
#     285,
#     139,
#     75,
#     353],
#    ['athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'tennis',
#     'athletics',
#     'athletics',
#     'rugby',
#     'athletics',
#     'athletics',
#     'athletics',
#     'athletics',
#     'tennis',
#     'tennis',
#     'athletics',
#     'tennis',
#     'athletics',
#     'tennis',
#     'athletics',
#     'athletics'],
#    [4.971523720775373,
#     5.330926023689377,
#     5.393352513932236,
#     5.604323288495864,
#     5.746208800747334,
#     5.810480652249584,
#     5.835546262039536,
#     5.839712579938434,
#     5.848773209188483,
#     5.862440553656661,
#     5.8981415260518695,
#     5.951521148292739,
#     5.956397354061834,
#     5.9565729039748065,
#     5.966417531828311,
#     5.97916700857245,
#     5.9935935048319475,
#     6.026730479417447,
#     6.0468269420724425,
#     6.0468269420724425,
#     6.047986072600503,
#     6.052802072587246,
#     6.0558910547316165,
#     6.075214042021335,
#     6.102321587065437,
#     6.102705121166473,
#     6.103955839618656,
#     6.105499661415366,
#     6.109339751436602,
#     6.125318172007006],
#    [['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics'],
#     ['athletics']]]},
#  {108: ['tennis',
#    [89,
#     359,
#     59,
#     382,
#     101,
#     393,
#     332,
#     489,
#     304,
#     503,
#     495,
#     451,
#     408,
#     326,
#     174,
#     127,
#     475,
#     449,
#     172,
#     112,
#     314,
#     104,
#     153,
#     434,
#     306,
#     211,
#     98,
#     505,
#     477,
#     205],
#    ['tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'rugby',
#     'cricket',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'tennis',
#     'rugby',
#     'tennis'],
#    [5.230994886235987,
#     5.2312815178896805,
#     5.239582064761335,
#     5.240527208355338,
#     5.245508968454165,
#     5.380493815059549,
#     5.395867036075572,
#     5.494614428316373,
#     5.494815553104859,
#     5.540206157264159,
#     5.556167480550588,
#     5.563207863689682,
#     5.5930016243107925,
#     5.611903535364145,
#     5.619537884441243,
#     5.625245162293573,
#     5.628522139566458,
#     5.676647526315175,
#     5.690180136021284,
#     5.702781473596273,
#     5.719398061553715,
#     5.72416946385406,
#     5.767195224410824,
#     5.781309111918708,
#     5.782379497808519,
#     5.785498333256867,
#     5.816354633205414,
#     5.822357140439974,
#     5.824296681171098,
#     5.829437106239044],
#    [['tennis'], ['tennis'], ['tennis'], ['tennis'], ['tennis']]]},
#  {109: ['rugby',
#    [288,
#     146,
#     362,
#     477,
#     95,
#     511,
#     54,
#     63,
#     152,
#     335,
#     103,
#     169,
#     187,
#     504,
#     409,
#     74,
#     25,
#     41,
#     385,
#     464,
#     333,
#     244,
#     424,
#     465,
#     268,
#     320,
#     196,
#     92,
#     485,
#     107],
#    ['rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'rugby'],
#    [5.068456810894322,
#     5.173924121889137,
#     5.180194560723606,
#     5.242790278982358,
#     5.321217062995683,
#     5.367479206456069,
#     5.377526186956018,
#     5.383259838902972,
#     5.400409890334746,
#     5.401146966068433,
#     5.402987015886145,
#     5.411408155946223,
#     5.415034182843576,
#     5.442140413129991,
#     5.444774614484063,
#     5.456497966118344,
#     5.469165098309344,
#     5.477073312154968,
#     5.480951183283216,
#     5.4852437046077345,
#     5.494548703618027,
#     5.525424102592307,
#     5.539492144120094,
#     5.562558472525934,
#     5.562859814705768,
#     5.563295210373951,
#     5.57057579934285,
#     5.572315963562526,
#     5.5730750991639955,
#     5.579866246645581],
#    [['rugby'], ['rugby'], ['rugby'], ['rugby'], ['rugby']]]}]

# %%
import pickle
with open('../results/result_Dhawal_frominteractive_test44.pickle', 'rb') as handle:
    completed = pickle.load(handle)
    
    
completed
# Out:
# [{44: ['football',
#    [80,
#     488,
#     27,
#     291,
#     413,
#     357,
#     508,
#     461,
#     179,
#     283,
#     478,
#     232,
#     79,
#     412,
#     152,
#     213,
#     248,
#     396,
#     319,
#     399,
#     97,
#     121,
#     175,
#     411,
#     151,
#     403,
#     279,
#     492,
#     133,
#     126],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football'],
#    [4.555165862068254,
#     5.15970128348402,
#     5.166928448285637,
#     5.231376076459701,
#     5.24329666253741,
#     5.246975762734809,
#     5.249510490885974,
#     5.254336969813415,
#     5.26098507403787,
#     5.2877283977406,
#     5.296835948385928,
#     5.35470073370069,
#     5.412046841526288,
#     5.413132694173248,
#     5.433080328086108,
#     5.470580909395981,
#     5.476845060864765,
#     5.496752317344613,
#     5.513008725652234,
#     5.522717537693555,
#     5.540909864324841,
#     5.564541840649832,
#     5.576423437502834,
#     5.580049984759933,
#     5.592928964963498,
#     5.592928964963498,
#     5.601725027147636,
#     5.605916417884871,
#     5.6094505273075,
#     5.610377359163919],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {45: ['football',
#    [120,
#     444,
#     233,
#     318,
#     474,
#     121,
#     478,
#     17,
#     283,
#     13,
#     179,
#     27,
#     435,
#     39,
#     448,
#     126,
#     305,
#     413,
#     286,
#     506,
#     99,
#     79,
#     461,
#     431,
#     213,
#     510,
#     396,
#     7,
#     492,
#     315],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football'],
#    [5.58509182050504,
#     5.635580426704158,
#     5.717573465596413,
#     5.721156306440129,
#     5.75407610699768,
#     5.7661842566899715,
#     5.835320835625652,
#     5.869199320535971,
#     5.869682714550196,
#     5.876025643725083,
#     5.897862085753843,
#     5.901310769207148,
#     5.911618438851967,
#     5.911618438851967,
#     5.918568359706977,
#     5.9221528939711305,
#     5.943350574616609,
#     5.9536247230629895,
#     5.954315702818515,
#     5.9580018307833855,
#     5.960597922518747,
#     5.965001574493581,
#     5.9666063984451725,
#     5.967833805788112,
#     5.969249826337314,
#     5.975600283951253,
#     5.998974360850767,
#     6.007058343902664,
#     6.009412706737834,
#     6.012689468821039],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {46: ['rugby',
#    [14,
#     63,
#     259,
#     130,
#     136,
#     338,
#     496,
#     486,
#     477,
#     18,
#     288,
#     43,
#     78,
#     292,
#     484,
#     258,
#     146,
#     140,
#     137,
#     159,
#     103,
#     64,
#     112,
#     394,
#     155,
#     432,
#     268,
#     424,
#     163,
#     336],
#    ['rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby',
#     'rugby'],
#    [2.901337771359389,
#     5.449163688320606,
#     5.681072407549958,
#     5.699725344259292,
#     5.718822723401001,
#     5.736219592607527,
#     5.801082096277715,
#     5.846398137176083,
#     5.873041335530547,
#     5.9338803330295775,
#     5.967944351290582,
#     6.002111005386924,
#     6.003223360569702,
#     6.011594177046744,
#     6.046754540603002,
#     6.054774662325406,
#     6.065953478532421,
#     6.077542578450553,
#     6.093814736590784,
#     6.0997276048094005,
#     6.112326568145338,
#     6.1479592756205275,
#     6.161462275733234,
#     6.1665851999321495,
#     6.172236155897705,
#     6.177128618275989,
#     6.179479803168106,
#     6.182634867134694,
#     6.193191313378077,
#     6.212943607908594],
#    [['rugby'], ['rugby'], ['rugby'], ['rugby'], ['rugby']]]},
#  {47: ['football',
#    [53,
#     197,
#     408,
#     489,
#     382,
#     305,
#     179,
#     104,
#     485,
#     31,
#     294,
#     54,
#     258,
#     431,
#     304,
#     288,
#     474,
#     414,
#     195,
#     465,
#     128,
#     461,
#     103,
#     135,
#     405,
#     188,
#     477,
#     314,
#     169,
#     478],
#    ['football',
#     'football',
#     'tennis',
#     'tennis',
#     'tennis',
#     'football',
#     'football',
#     'tennis',
#     'football',
#     'football',
#     'rugby',
#     'rugby',
#     'rugby',
#     'football',
#     'tennis',
#     'rugby',
#     'football',
#     'football',
#     'tennis',
#     'rugby',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'cricket',
#     'football',
#     'football'],
#    [5.653056508180542,
#     5.807075296605555,
#     5.875392651269761,
#     5.919453610880191,
#     5.927642300255158,
#     5.992739466662631,
#     6.00458559649465,
#     6.004720819752307,
#     6.014477397807748,
#     6.017258025856191,
#     6.028199068773939,
#     6.029617906252168,
#     6.0427746939105775,
#     6.060901826490638,
#     6.085433280416651,
#     6.087009211201439,
#     6.106262208468766,
#     6.114625329608816,
#     6.118128528395854,
#     6.118719476582155,
#     6.123180212622034,
#     6.135589959648806,
#     6.138953299248666,
#     6.139351280742838,
#     6.144553638499746,
#     6.145647296063755,
#     6.157049081468065,
#     6.1591942294503905,
#     6.165140659279733,
#     6.166311203036019],
#    [['tennis'], ['football'], ['football'], ['football'], ['football']]]},
#  {48: ['football',
#    [396,
#     352,
#     502,
#     488,
#     27,
#     179,
#     54,
#     357,
#     310,
#     435,
#     39,
#     201,
#     424,
#     283,
#     233,
#     268,
#     152,
#     329,
#     38,
#     80,
#     399,
#     135,
#     79,
#     175,
#     477,
#     121,
#     65,
#     505,
#     413,
#     412],
#    ['football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'football',
#     'football',
#     'football',
#     'rugby',
#     'football',
#     'football',
#     'tennis',
#     'football',
#     'football'],
#    [1.1416746208726627,
#     4.959068805482769,
#     5.146738111911185,
#     5.183924445387216,
#     5.22805672133826,
#     5.237718701819713,
#     5.292911711143639,
#     5.360674547674052,
#     5.390300592850093,
#     5.391448915310183,
#     5.391448915310183,
#     5.398301307762444,
#     5.400770881860517,
#     5.405168154009267,
#     5.4190499827823615,
#     5.426834105914245,
#     5.430852924399002,
#     5.437891934382484,
#     5.442558222747062,
#     5.4503292862824635,
#     5.463344642986224,
#     5.466450386598884,
#     5.472103145340708,
#     5.474008326529409,
#     5.4766751050297104,
#     5.489826475744251,
#     5.504992979888952,
#     5.5050791446453475,
#     5.514822529502945,
#     5.5169674450234805],
#    [['football'], ['football'], ['football'], ['football'], ['football']]]},
#  {49: ['cricket',
#    [383,
#     84,
#     230,
#     298,
#     423,
#     452,
#     483,
#     50,
#     110,
#     161,
#     308,
#     302,
#     314,
#     225,
#     156,
#     350,
#     122,
#     445,
#     284,
#     210,
#     8,
#     86,
#     219,
#     457,
#     473,
#     123,
#     398,
#     157,
#     418,
#     12],
#    ['cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket',
#     'cricket'],
#    [0.037150589206678616,
#     3.664605030406387,
#     4.229538067513466,
#     4.492787098370926,
#     4.500151786986902,
#     5.006059060913319,
#     5.116354288821678,
#     5.2018978468358394,
#     5.473030603962056,
#     5.489228194084637,
#     5.516307226375001,
#     5.572109403477255,
#     5.593558403214384,
#     5.651453009017978,
#     5.720056384665764,
#     5.7679689506171545,
#     5.7940582084507035,
#     5.874641179433308,
#     5.92677513470313,
#     5.937011907204584,
#     5.960553473992645,
#     6.02745130790535,
#     6.029105786388757,
#     6.046068134505685,
#     6.0544398577263605,
#     6.060393918139845,
#     6.084804593728218,
#     6.101643384616426,
#     6.1057391604332905,
#     6.1144540279769375],
#    [['cricket'], ['cricket'], ['cricket'], ['cricket'], ['cricket']]]}]
